# %%
import matplotlib.pyplot as plt
import pandas as pd 
import numpy as np
import seaborn as sb

# %%
iris = pd.read_csv("Iris.csv")

# %%
x=iris['PetalLengthCm']
plt.boxplot(x)
# Out:
# {'whiskers': [<matplotlib.lines.Line2D at 0x258d494efc0>,
#   <matplotlib.lines.Line2D at 0x258d494f2f0>],
#  'caps': [<matplotlib.lines.Line2D at 0x258d494f560>,
#   <matplotlib.lines.Line2D at 0x258d494f860>],
#  'boxes': [<matplotlib.lines.Line2D at 0x258d494edb0>],
#  'medians': [<matplotlib.lines.Line2D at 0x258d494fb90>],
#  'fliers': [<matplotlib.lines.Line2D at 0x258d494fec0>],
#  'means': []}

# %%
iris.boxplot('PetalLengthCm','Species')
# Out:
# <Axes: title={'center': 'PetalLengthCm'}, xlabel='Species'>

# %%
iris.drop("Id", axis=1).boxplot()
# Out:
# <Axes: >

# %%
array = np.array(
            [23, 56, 87, 87, 98,  
            12, 76, 98, 34, 87,  
            67, 23, 87, 56, 34,  
            26, 85, 47, 35, 86,
            76, 45, 86, 34, 37]
        )
figure, axis = plt.subplots(figsize = (8, 3))  
axis.hist(array, bins = [20, 40, 60, 80, 100])
plt.show()

# %%
iris.head()
plt.figure(figsize = (10, 7)) 
x = iris["SepalLengthCm"] 
plt.hist(x, bins = 20, color = "green") 
plt.title("Sepal Length in cm") 
plt.xlabel("Sepal_Length_cm") 
plt.ylabel("Count")
# Out:
# Text(0, 0.5, 'Count')

# %%
x =[5, 7, 8, 7, 2, 17, 2, 9,4, 11, 12, 9, 6]  
y =[99, 86, 87, 88, 100, 86,103, 87, 94, 78, 77, 85, 86] 
plt.scatter(x, y, c ="blue") 
plt.show()

# %%
x1 = [89, 43, 36, 36, 95, 10, 66, 34, 38, 20] 
y1 = [21, 46, 3, 35, 67, 95, 53, 72, 58, 10] 

x2 = [26, 29, 48, 64, 6, 5, 36, 66, 72, 40] 
y2 = [26, 34, 90, 33, 38, 20, 56, 2, 47, 15]

plt.scatter(x1, y1, c ="pink",linewidths = 2,marker ="s",edgecolor ="green",s = 50) 
plt.scatter(x1, y1, c ="pink") 
plt.scatter(x2, y2, c ="yellow",linewidths = 2,marker ="^",edgecolor ="red",s = 200) 
plt.scatter(x2, y2, c ="yellow") 
plt.xlabel("X-axis") 
plt.ylabel("Y-axis") 
plt.show()

# %%
sb.set_style('whitegrid') 
sb.scatterplot(data=iris, x='SepalLengthCm', y='SepalWidthCm', hue='Species') 
plt.plot()
plt.savefig("plot_1.pdf",  format="pdf")

# %%
#d = {'Column 1': [i for i in range(10)], 'Column 2': [i * i for i in range(10)]} 
d = {'Column 1': [100, 32, 44, 22, 12, 43, 22, 44, 11, 4], 'Column 2': [12, 44, 223, 54, 322, 34, 53, 23, 76, 87]} 
df = pd.DataFrame(d) 
print(df) 
df.plot(style=['o', 'rx']) 
df.plot(style=['o']) 
plt.savefig("plot_2.pdf",  format="pdf", bbox_inches="tight") 
plt.show()
# Out:
#    Column 1  Column 2
# 0       100        12
# 1        32        44
# 2        44       223
# 3        22        54
# 4        12       322
# 5        43        34
# 6        22        53
# 7        44        23
# 8        11        76
# 9         4        87

# %%
x=[1, 2, 3, 4, 5, 6]
y=[4, 11, 6, 31, 4, 20] 
#plt.plot(x,y,marker=",")#pixel 
#plt.plot(x,y,marker="*")#star 
#plt.plot(x,y,marker="o")#circle 
#plt.plot(x,y,marker=".")#point 
#plt.plot(x,y,marker="s")#Square 
#plt.plot(x,y,marker="D")#Diamond 
#plt.plot(x,y,marker="p")#Pentagon 
#plt.plot(x,y,marker="H")#Hexagon 
#plt.plot(x,y,marker="v")#Triangle Down 
plt.plot(x,y,marker="^")#Triangle up 
#plt.plot(x,y,marker=">")#Triangle Right 
#plt.plot(x,y,marker="<")#Triangle Left 
plt.show()

# %%
x=[1,2,6] 
y=[4,5,6] 
plt.plot(x,y,marker="o",ms=10)

# %%
x=[1,2,6] 
y=[4,5,6] 
#plt.plot(x,y,"o:r")# : for dotted line 
#plt.plot(x,y,"o:b")#: for dotted line
#plt.plot(x,y,"o-b")#: for solid line
#plt.plot(x,y,"o--b")#: for dashed line 
plt.plot(x,y,"o-.b")#: for Dashed/dotted line
